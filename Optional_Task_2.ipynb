# %% [markdown]
# <a href="https://colab.research.google.com/github/pavankhedekar/Datasets_-Repo/blob/main/Optional_Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d25aea54-af22-4df3-a7e2-955ed95fb1cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d25aea54-af22-4df3-a7e2-955ed95fb1cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = '/content/insurance.csv'
df = pd.read_csv(filepath)
print("dataset loded")
# Out:
# dataset loded

# %%
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
# Basic Info
print("Dataset Shape:", df.shape)
print("\nDataset Info:",df.info())
# Out:
# Dataset Shape: (1338, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
#
# Dataset Info: None

# %%
# Statistical Summary
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
# Check Missing Values

df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
# Distribution of Age
sns.histplot(df['age'])
plt.title("Age Distribution")
plt.show()

# Distribution of BMI
sns.histplot(df['bmi'])
plt.title("BMI Distribution")
plt.show()

# %%
# Count Plot

# Sex
plt.subplot(2,2,1)
sns.countplot(x='sex', data=data)
plt.title("Count of Sex")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.show()

# Smoker
plt.subplot(2,2,2)
sns.countplot(x='smoker', data=data)
plt.title("Count of Smoker")
plt.xlabel("Smoker")
plt.ylabel("Count")
plt.show()

# Region
plt.subplot(2,2,3)
sns.countplot(x='region', data=data)
plt.title("Count of Region")
plt.xlabel("Region")
plt.ylabel("Count")
plt.show()

# %%
# Expenses by Smoker

sns.boxplot(x='smoker', y='expenses', data=df)
plt.title("Expenses by Smoker Status")
plt.show()

# %%
# Expenses by Region

sns.barplot(x='region', y='expenses', data=df)
plt.title("Average Expenses by Region")
plt.show()

# %%
# BMI vs Expenses

sns.scatterplot(x='bmi', y='expenses', hue='smoker', data=df)
plt.title("BMI vs Expenses")
plt.show()

# %%
# Convert categorical variables to numerical using one-hot encoding
df_encoded = pd.get_dummies(df, columns=['sex', 'smoker', 'region'], drop_first=True)

# Calculate the correlation matrix for the encoded DataFrame
corr = df_encoded.corr()

sns.heatmap(corr)
plt.title("Correlation Heatmap")
plt.show()

# %%
# find mean,max,min

#1.Find the average insurance expenses
avg_expenses = df['expenses'].mean()
print(" average insurance charges : ",avg_expenses)

#2.Find the maximum expenses
max_expenses = df['expenses'].max()
print("Maximum expenses : ",max_expenses)

#3.Find the minimum expenses
min_expenses = df['expenses'].min()
print("Minimum expenses : ",min_expenses)
# Out:
#  average insurance charges :  13270.422414050823
# Maximum expenses :  63770.43
# Minimum expenses :  1121.87
