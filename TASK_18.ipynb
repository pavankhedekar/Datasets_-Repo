# %% [markdown]
# <a href="https://colab.research.google.com/github/pavankhedekar/Datasets_-Repo/blob/main/TASK_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-63a357e4-616b-47f9-b758-f5704529a83f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63a357e4-616b-47f9-b758-f5704529a83f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = '/content/ford_car_dataset.csv'
df = pd.read_csv(filepath)
df
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1        Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2        Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3       Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4       Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 17961    B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962    B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963    Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964       KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965    Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...

# %%
# Display the first 10 rows
print("First 10 rows:")
print(df.head(10))

# Display the last 5 rows
print("\nLast 5 rows:")
print(df.tail(5))

# Check the shape
print("\nShape of dataset:", df.shape)

# Check data types
print("\nData types:")
print(df.dtypes)

# Observations:
# 1. The dataset contains rows and columns
# 2. Each column has a specific data type (int, float, object/string).
# 3. Numerical columns likely represent car attributes such as price, mileage, engine size, etc.
# 4. Object (string) columns may represent categorical data such as model name, fuel type, transmission.
# 5. The dataset seems structured in a tabular format suitable for further analysis (cleaning, visualization, ML).
# Out:
# First 10 rows:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5   Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6     Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7   Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8     Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9    Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0
#
# Last 5 rows:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# ...

# %%
# 1.Find the total number of missing values in each column
print("Missing values per column:")
print(df.isnull().sum())

# 2.Identify duplicate rows
duplicate_rows = df[df.duplicated()]
print("\nNumber of duplicate rows:", duplicate_rows.shape[0])

# 3.Remove duplicate
df_cleaned = df.drop_duplicates()

print("\nShape after removing duplicates:", df_cleaned.shape)
# Out:
# Missing values per column:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64
#
# Number of duplicate rows: 154
#
# Shape after removing duplicates: (17812, 9)

# %%
# 1. Generate statistical summary
print("Statistical Summary:")
print(df.describe())

# 2. Identify min, max, mean, and median for key columns
# Price
print("\nPrice Stats:")
print("Min:", df['price'].min())
print("Max:", df['price'].max())
print("Mean:", df['price'].mean())
print("Median:", df['price'].median())

# MPG
print("\nMPG Stats:")
print("Min:", df['mpg'].min())
print("Max:", df['mpg'].max())
print("Mean:", df['mpg'].mean())
print("Median:", df['mpg'].median())

# Year
print("\nYear Stats:")
print("Min:", df['year'].min())
print("Max:", df['year'].max())
print("Mean:", df['year'].mean())
print("Median:", df['year'].median())
# Out:
# Statistical Summary:
#                year         price        mileage           tax           mpg  \
# count  17966.000000  17966.000000   17966.000000  17966.000000  17966.000000
# mean    2016.866470  12279.534844   23362.608761    113.329456     57.906980
# std        2.050336   4741.343657   19472.054349     62.012456     10.125696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000    9987.000000     30.000000     52.300000
# 50%     2017.000000  11291.000000   18242.500000    145.000000     58.900000
# 75%     2018.000000  15299.000000   31060.000000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17966.000000
# mean       1.350807
# std        0.432367
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000
#
# Price Stats:
# Min: 495
# Max: 54995
# ...

# %%
# Identify categorical columns
categorical_cols = df.select_dtypes(include='object').columns
print("Categorical Columns:", categorical_cols)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
sns.countplot(x='model', data=df)
plt.title("Count of model")
plt.xlabel("model")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

plt.subplot(2,2,2)
sns.countplot(x='transmission', data=df)
plt.title("Count of transmission")
plt.xlabel("transmission")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

plt.subplot(2,2,3)
sns.countplot(x='fuelType', data=df)
plt.title("Count of fuelType")
plt.xlabel("fuelType")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
# Out:
# Categorical Columns: Index(['model', 'transmission', 'fuelType'], dtype='object')

# %%
# numeric columns
numeric_cols = df.select_dtypes(include='number')

# correlation matrix
corr_matrix = numeric_cols.corr()

# Plot heatmap
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix)
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %%
# One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=['fuelType', 'transmission'])
df_encoded.head()
# Out:
#      model  year  price  mileage  tax   mpg  engineSize  fuelType_Diesel  \
# 0   Fiesta  2017  12000    15944  150  57.7         1.0            False
# 1    Focus  2018  14000     9083  150  57.7         1.0            False
# 2    Focus  2017  13000    12456  150  57.7         1.0            False
# 3   Fiesta  2019  17500    10460  145  40.3         1.5            False
# 4   Fiesta  2019  16500     1482  145  48.7         1.0            False
#
#    fuelType_Electric  fuelType_Hybrid  fuelType_Other  fuelType_Petrol  \
# 0              False            False           False             True
# 1              False            False           False             True
# 2              False            False           False             True
# 3              False            False           False             True
# 4              False            False           False             True
#
#    transmission_Automatic  transmission_Manual  transmission_Semi-Auto
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
df_encoded = pd.get_dummies(df, drop_first=True)
print(df_encoded.shape)
print(df_encoded.columns.to_list())
# Out:
# (17966, 35)
# ['year', 'price', 'mileage', 'tax', 'mpg', 'engineSize', 'model_ C-MAX', 'model_ EcoSport', 'model_ Edge', 'model_ Escort', 'model_ Fiesta', 'model_ Focus', 'model_ Fusion', 'model_ Galaxy', 'model_ Grand C-MAX', 'model_ Grand Tourneo Connect', 'model_ KA', 'model_ Ka+', 'model_ Kuga', 'model_ Mondeo', 'model_ Mustang', 'model_ Puma', 'model_ Ranger', 'model_ S-MAX', 'model_ Streetka', 'model_ Tourneo Connect', 'model_ Tourneo Custom', 'model_ Transit Tourneo', 'model_Focus', 'transmission_Manual', 'transmission_Semi-Auto', 'fuelType_Electric', 'fuelType_Hybrid', 'fuelType_Other', 'fuelType_Petrol']

# %%
# Select only numerical data
numeric_data = df_encoded.select_dtypes(include=[np.number]).columns

# Initialize StandardScaler
scaler = StandardScaler()

# Fit and transform numeric features
scaled_data = scaler.fit_transform(df_encoded[numeric_data])

# Show first 5 rows
print(scaled_df.head())
# Out:
#        year     price   mileage       tax       mpg  engineSize
# 0  0.065128 -0.058959 -0.380998  0.591358 -0.020442   -0.811386
# 1  0.552866  0.362875 -0.733359  0.591358 -0.020442   -0.811386
# 2  0.065128  0.151958 -0.560132  0.591358 -0.020442   -0.811386
# 3  1.040605  1.101082 -0.662640  0.510727 -1.738890    0.345070
# 4  1.040605  0.890166 -1.123724  0.510727 -0.909294   -0.811386

# %%
# 1. Load and clean the data
df = pd.read_csv("ford_car_dataset.csv")

# 2. Check for missing values
print(df.isnull().sum())

# 3. Check for duplicates
print("Duplicate rows:", df.duplicated().sum())

# Remove duplicates
df_cleaned = df.drop_duplicates()

# 5. Preview first 5 rows
print(df_cleaned.head())
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64
# Duplicate rows: 154
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
# countplot
plt.subplot(2,2,1)
sns.countplot(x='transmission', data=df)
plt.title("Count of Transmission Type")
plt.xlabel("Transmission Type")
plt.ylabel("Count")
plt.show()


# Histogram
sns.histplot(df['year'], kde=True)
plt.title("Distribution of Year")
plt.xlabel("Year")
plt.ylabel("Frequency")
plt.show()


# Heatmap
numerical_cols = df.select_dtypes(include=np.number).columns
corr = df[numerical_cols].corr()
sns.heatmap(corr)
plt.title("Correlation Heatmap")
plt.show()

# %%
X = df.drop("price", axis=1)
y = df["price"]
X.columns.tolist()
# Out:
# ['model',
#  'year',
#  'transmission',
#  'mileage',
#  'fuelType',
#  'tax',
#  'mpg',
#  'engineSize']

# %%
# Identify categorical features
categorical_features = df.select_dtypes(include=['object']).columns
print(categorical_features.tolist())

# Encode categorical variables
df_encoded = pd.get_dummies(df, drop_first=True)

# Show shape and column names after encoding
print(df_encoded.shape)
print(df_encoded.columns.to_list())
# Out:
# ['model', 'transmission', 'fuelType']
# (17966, 35)
# ['year', 'price', 'mileage', 'tax', 'mpg', 'engineSize', 'model_ C-MAX', 'model_ EcoSport', 'model_ Edge', 'model_ Escort', 'model_ Fiesta', 'model_ Focus', 'model_ Fusion', 'model_ Galaxy', 'model_ Grand C-MAX', 'model_ Grand Tourneo Connect', 'model_ KA', 'model_ Ka+', 'model_ Kuga', 'model_ Mondeo', 'model_ Mustang', 'model_ Puma', 'model_ Ranger', 'model_ S-MAX', 'model_ Streetka', 'model_ Tourneo Connect', 'model_ Tourneo Custom', 'model_ Transit Tourneo', 'model_Focus', 'transmission_Manual', 'transmission_Semi-Auto', 'fuelType_Electric', 'fuelType_Hybrid', 'fuelType_Other', 'fuelType_Petrol']

# %%
# Select only numerical data
numeric_data = df_encoded.select_dtypes(include=[np.number]).columns

# Initialize StandardScaler
scaler = StandardScaler()

# Fit and transform numeric features
df_scaled = scaler.fit_transform(df[numeric_features])

# Convert back to DataFrame
df_scaled = pd.DataFrame(df_scaled, columns=numeric_features)

print(df_scaled.head())
# Out:
#        year     price   mileage       tax       mpg  engineSize
# 0  0.065128 -0.058959 -0.380998  0.591358 -0.020442   -0.811386
# 1  0.552866  0.362875 -0.733359  0.591358 -0.020442   -0.811386
# 2  0.065128  0.151958 -0.560132  0.591358 -0.020442   -0.811386
# 3  1.040605  1.101082 -0.662640  0.510727 -1.738890    0.345070
# 4  1.040605  0.890166 -1.123724  0.510727 -0.909294   -0.811386
